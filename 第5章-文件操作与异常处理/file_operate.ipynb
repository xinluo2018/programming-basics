# %% [markdown]
# ### 文件操作与异常处理

# %%
f = open('第5章-文件操作与异常处理/file.txt', 'r')
content = f.read()
print(content)
f.close()  # 关闭文件
# Out:
# date: 2025.9.1
# place: yunnan university
# people: students

# %%
## with...as...上下文管理，自动关闭文件
with open('第5章-文件操作与异常处理/file.txt', 'r') as file:
    content = file.read()
print(content)
# Out:
# date: 2025.9.1
# place: yunnan university
# people: students

# %%
## 写出
with open('第5章-文件操作与异常处理/file_2.txt', 'w') as f:
    f.write('Hello, world!\n')
    f.write('This is a new file.\n')

# %%
## 追加
with open('第5章-文件操作与异常处理/file_2.txt', 'a') as f:
    f.write('This is a sentence using "a" mode.\n')

# %% [markdown]
# #### 文件操作

# %%
import os 
# os.getcwd()
# os.listdir()  ##  -> ls
# os.listdir('第5章-文件操作与异常处理') # 列出当前目录下的所有文件和文件夹
# os.rename('第5章-文件操作与异常处理/tmp2.txt', 'tmp2.txt')  # 重命名文件/移动
# os.remove('tmp2.txt')  # 删除文件

# %%
### glob模块:文件路径匹配
## os 模块
# import os
# files = [f for f in os.listdir('第5章-文件操作与异常处理') if f.endswith('.txt')]
# files

import glob 
# files = glob.glob('第5章-文件操作与异常处理/*.txt')  # 匹配所有txt文件
files = glob.glob('第5章-文件操作与异常处理/[!tmp]*.txt')  # 匹配所有txt文件，排除tmp开头的
files
# Out:
# ['第5章-文件操作与异常处理\\file.txt', '第5章-文件操作与异常处理\\file_2.txt']

# %% [markdown]
# #### assert: 断言

# %%
### 验证程序内部假设
def calculate_area(width, height):
    assert width > 0, "宽度必须为正数"
    assert height > 0, "高度必须为正数"
    return width * height

# print(calculate_area(5, 3))  # 正常
print(calculate_area(-2, 4)) # 触发断言
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[13], line 8
#       5     return width * height
#       7 # print(calculate_area(5, 3))  # 正常
# ----> 8 print(calculate_area(-2, 4)) # 触发断言
#
# Cell In[13], line 3, in calculate_area(width, height)
#       2 def calculate_area(width, height):
# ----> 3     assert width > 0, "宽度必须为正数"
#       4     assert height > 0, "高度必须为正数"
#       5     return width * height
#
# AssertionError: 宽度必须为正数

# %% [markdown]
# #### 异常处理

# %%
# 读入一个不存在文件
with open('aaa.txt', 'r') as f:
  content = f.read()
# # ## 索引错误
# list1 = [1, 2, 3]
# a = list1[3]  # 索引错误，索引超出范围
print(111) 
print(222)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[16], line 2
#       1 # 读入一个不存在文件
# ----> 2 with open('aaa.txt', 'r') as f:
#       3   content = f.read()
#       4 # # ## 索引错误
#       5 # list1 = [1, 2, 3]
#       6 # a = list1[3]  # 索引错误，索引超出范围
#
# File c:\Users\HP\miniconda3\envs\gis-course\lib\site-packages\IPython\core\interactiveshell.py:324, in _modified_open(file, *args, **kwargs)
#     317 if file in {0, 1, 2}:
#     318     raise ValueError(
#     319         f"IPython won't let you open fd={file} by default "
#     320         "as it is likely to crash IPython. If you know what you are doing, "
#     321         "you can use builtins' open."
#     322     )
# --> 324 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'aaa.txt'

# %%
## 基本语法，如果except后没有错误类型，那么会捕获所有异常
try:
  with open('aaa.txt', 'r') as f:
    content = f.read()
except FileNotFoundError:
  print(f"文件未找到, 请检查文件路径！！")

print(111) 
print(222)
# Out:
# 文件未找到, 请检查文件路径！！
# 111
# 222

# %%
# try:
#   num = int(input("请输入: "))
#   result = 10 / num
#   print(result)
# except ZeroDivisionError:
#   print(f"除数不能为零")

## 捕获多个异常
try:
  num = int(input("请输入: "))
  print(10/num)
except ZeroDivisionError:
  print("除数不能为零")
except ValueError:
  print("输入的不是一个数字")

print(123)
# Out:
# 输入的不是一个数字
# 123
