# %%
print("Hello, World!")
# Out:
# Hello, World!

# %%
aaa = 6
bbb = 100
print(aaa * bbb)

# %%
a = 7
b = 3
print(a + b)
print(a - b)
print(a * b)
print(a / b)
print(a // b)
print(a % b)
# Out:
# 10
# 4
# 21
# 2.3333333333333335
# 2
# 1

# %%
a, b = 7, 3
print(a <= b)
# Out:
# False

# %%
print(a>0 or b>10)
# Out:
# True

# %%
a = -10.2
int(a)
print(type(a))
# Out:
# <class 'float'>

# %%
# list
list1 = [1, 'hellow', 3, 4, 5]
# print(type(list1))
# list1[1] = 'world'
# list1.pop(2)
print(list1[1:4])  # slicing
# Out:
# ['hellow', 3, 4]

# %%
## string
a = "Hello world"
type(a) 
a[0:5]
print(a *3)
# Out:
# Hello worldHello worldHello world
